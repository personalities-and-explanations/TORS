# %%
import pandas as pd
from scipy.stats import chi2_contingency, mannwhitneyu
import numpy as np
import pandas as pd
import nltk
from nltk.stem import PorterStemmer
import pandas as pd
from nltk.stem import PorterStemmer

trait_terms = {
    "Openness": list(set([
        "original", "novelty", "curious", "different", "ingenious", "active",
        "imaginative", "inventive", "artistic", "aesthetic", "reflective",
        "sophisticated", "musical", "literate", "unpredictable", "fearless",
        "open", "creative", "adventurous", "explore", "brave", "openness",
        "creative", "imaginative", "intellectual", "philosophical", "artistic",
        "inventive", "complex", "deep", "intelligent", "curious", "unconventional",
        "wide interests", "adventurous", "introspective", "innovative", "original",
        "reflective", "exploratory", "insightful", "open-minded"
    ])),
    "Conscientiousness": list(set([
        "conscientious", "thorough", "accurate", "reliable", "organize", "organized",
        "diligent", "persevere", "persevering", "efficient", "plan", "planning",
        "persist", "persistent", "focus", "focused", "careful", "work", "painstaking",
        "meticulous", "scrupulous", "particular", "selfless", "caring",
        "organized", "thorough", "efficient", "responsible", "practical", "systematic",
        "reliable", "hardworking", "persevering", "careful", "disciplined",
        "detail-oriented", "goal-oriented", "self-controlled", "consistent",
        "deliberate", "achievement-oriented", "precise", "dutiful", "structured"
    ])),
    "Extraversion": list(set([
        "talkative", "outgoing", "energetic", "enthusiastic", "boisterous", "assertive",
        "eager", "friendly", "sociable", "lively", "social", "open", "chatty",
        "meet", "interaction", "energized", "public",
        "talkative", "energetic", "enthusiastic", "outgoing", "assertive", "bold",
        "active", "adventurous", "spontaneous", "sociable", "lively", "cheerful",
        "fun-loving", "expressive", "excitable", "gregarious", "action-oriented",
        "spirited", "upbeat", "positive"
    ])),
    "Agreeableness": list(set([
      "accommodating", "affectionate", "agree", "agreeable", "agreement", "altruistic",
    "caring", "cooperate", "cooperative", "compassionate", "considerate",
    "easygoing", "empathize", "empathetic", "empathy", "forgive", "forgiving",
    "friend", "friendly", "generous", "help", "helpful", "kind", "pleasant",
    "polite", "soft-hearted", "supportive", "sympathetic", "tolerant", "trust",
    "trusting", "understanding", "welcoming", "connection"
    ])),
    "Neuroticism_High": list(set([
        "neurotic", "depressed", "blue", "agitated", "stressed", "tense", "worried",
        "worry", "emotionally", "emotional", "unstable", "upset", "moody",
        "restless", "nervous", "anxiety", "compulsive", "obsessed", "indecisive",
        "maladjusted", "anxious", "uneasy", "irritable",
        "anxious", "nervous", "tense", "moody", "high-strung", "easily upset",
        "touchy", "temperamental", "self-pitying", "unstable", "insecure", "irritable",
        "emotional", "vulnerable", "defensive", "over-sensitive", "pessimistic",
        "self-conscious", "brooding", "prone to worry"
    ])),
    "Neuroticism_Low": list(set([
        "calm", "relaxed", "safe", "comfort", "secure", "reassured", "composed",
        "stable", "peaceful", "steady", "serene", "content", "relief",
        "calm", "relaxed", "stable", "even-tempered", "resilient", "emotionally stable",
        "secure", "unflappable", "unemotional", "collected", "confident",
        "self-assured", "poised", "composed", "content", "unworried", "steady",
        "balanced", "laid-back", "peaceful"
    ]))
}

# %%
top_words_neuroticism_explanation = pd.DataFrame({
    "Word": [
        "ajudar", "alívio", "tensão", "conforto", "promover", "acalmar", "interior",
        "seguro", "interno", "aliviar", "catarse", "liberação", "escape", "aceitação",
        "liberar", "emocional", "sensação", "encontrar", "proporcionar", "oferecer",
        "força", "espaço", "permitir", "reconfortante", "calmo", "tranquilidade",
        "confiança", "positivo", "serenidade", "sentimento", "emoção", "equilíbrio",
        "compreensão", "resiliência", "mente", "suave", "mensagem", "pessoal"
    ]
})


translation_dict = {
    "ajudar": "help", "alívio": "relief", "tensão": "tension", "conforto": "comfort",
    "promover": "promote", "acalmar": "calm", "interior": "inner", "seguro": "safe",
    "interno": "internal", "aliviar": "relieve", "catarse": "catharsis",
    "liberação": "release", "escape": "escape", "aceitação": "acceptance",
    "liberar": "release", "emocional": "emotional", "sensação": "sensation",
    "encontrar": "find", "proporcionar": "provide", "oferecer": "offer",
    "força": "strength", "espaço": "space", "permitir": "allow",
    "reconfortante": "comforting", "calmo": "calm", "tranquilidade": "tranquility",
    "confiança": "trust", "positivo": "positive", "serenidade": "serenity",
    "sentimento": "feeling", "emoção": "emotion", "equilíbrio": "balance",
    "compreensão": "understanding", "resiliência": "resilience", "mente": "mind",
    "suave": "soft", "mensagem": "message", "pessoal": "personal"
}



top_words_neuroticism_explanation["Word_EN"] = top_words_neuroticism_explanation["Word"].map(translation_dict)

# %%
top_words_agreeableness_explanation = pd.DataFrame({
    "Word": [
        "conexão", "acolhedor", "empatia", "coração", "caloroso",
        "humano", "genuíno", "compreensão", "valorizar", "empatir",
        "alma", "autêntico", "autenticidade", "ressoar", "união",
        "harmonia", "positivo", "sincero", "profundamente", "promover",
        "transmitir", "sentimento", "suave", "emocional", "celebrar",
        "refletir", "aprecer", "melodia", "profundo", "ressoo",
        "espírito", "evocar"
    ]
})


translation_dict_agreeableness = {
    "conexão": "connection",
    "acolhedor": "welcoming",
    "empatia": "empathy",
    "coração": "heart",
    "caloroso": "warm",
    "humano": "human",
    "genuíno": "genuine",
    "compreensão": "understanding",
    "valorizar": "value",
    "empatir": "empathize",
    "alma": "soul",
    "autêntico": "authentic",
    "autenticidade": "authenticity",
    "ressoar": "resonate",
    "união": "union",
    "harmonia": "harmony",
    "positivo": "positive",
    "sincero": "sincere",
    "profundamente": "deeply",
    "promover": "promote",
    "transmitir": "transmit",
    "sentimento": "feeling",
    "suave": "soft",
    "emocional": "emotional",
    "celebrar": "celebrate",
    "refletir": "reflect",
    "aprecer": "appreciate",
    "melodia": "melody",
    "profundo": "deep",
    "ressoo": "resound",
    "espírito": "spirit",
    "evocar": "evoke"
}



top_words_agreeableness_explanation["Word_EN"] = top_words_agreeableness_explanation["Word"].map(translation_dict_agreeableness)

# %%
translation_dict_openness = {
    "exploração": "exploration", "estimular": "stimulate", "imaginação": "imagination",
    "explorar": "explore", "convenção": "convention", "único": "unique",
    "inovador": "innovative", "jornada": "journey", "desafiar": "challenge",
    "convencional": "conventional", "despertar": "awaken", "rico": "rich",
    "viagem": "trip", "sonoro": "sonorous", "convidar": "invite",
    "evocar": "evoke", "pensamento": "thought", "fusão": "fusion",
    "interpretação": "interpretation", "nuance": "nuance", "conver": "converse",
    "camada": "layer", "contemplação": "contemplation", "musical": "musical",
    "poético": "poetic", "introspecção": "introspection", "auditivo": "auditory",
    "complexo": "complex", "introspectivo": "introspective", "ouvinte": "listener",
    "profundo": "deep", "apreciar": "appreciate", "pessoal": "personal"
}


top_words_openness_explanation = pd.DataFrame({
    "Word": [
        "exploração", "estimular", "imaginação", "explorar", "convenção",
        "único", "inovador", "jornada", "desafiar", "convencional",
        "despertar", "rico", "viagem", "sonoro", "convidar",
        "evocar", "pensamento", "fusão", "interpretação", "nuance",
        "conver", "camada", "contemplação", "musical", "poético",
        "introspecção", "auditivo", "complexo", "introspectivo", "ouvinte",
        "profundo", "apreciar", "pessoal"
    ]
})


top_words_openness_explanation["Word_EN"] = top_words_openness_explanation["Word"].map(translation_dict_openness)

# %%
top_words_conscientiousness_explanation = pd.DataFrame({
    "Word": [
        "foco", "Foco", "precisão", "concentração", "estrutura", "detalhe",
        "determinação", "dedicação", "ordem", "tarefa", "planejamento",
        "clareza", "produtividade", "cuidadoso", "valorizar", "cuidadosamente",
        "refletir", "equilíbrio", "motivação", "atenção", "manter", "aprecer",
        "equilibrar", "desafio", "ressoar", "mente", "trilha", "ideal",
        "reflexão", "ressoo", "apreciar", "harmonia", "inspirar", "música", "ambiente"
    ]
})


translation_dict_conscientiousness = {
    "foco": "focus", "precisão": "precision", "concentração": "concentration",
    "estrutura": "structure", "detalhe": "detail", "determinação": "determination",
    "dedicação": "dedication", "ordem": "order", "tarefa": "task",
    "planejamento": "planning", "clareza": "clarity", "produtividade": "productivity",
    "cuidadoso": "careful", "valorizar": "value", "cuidadosamente": "carefully",
    "refletir": "reflect", "equilíbrio": "balance", "motivação": "motivation",
    "atenção": "attention", "manter": "maintain", "aprecer": "appreciate",
    "equilibrar": "balance", "desafio": "challenge", "ressoar": "resonate",
    "mente": "mind", "trilha": "track", "ideal": "ideal", "reflexão": "reflection",
    "ressoo": "resound", "apreciar": "appreciate", "harmonia": "harmony",
    "inspirar": "inspire", "música": "music", "ambiente": "environment"
}


top_words_conscientiousness_explanation["Word_EN"] = top_words_conscientiousness_explanation["Word"].map(translation_dict_conscientiousness)

# %%
top_words_extroversion_explanation = pd.DataFrame({
    "Word": [
        "animar", "interação", "encontro", "vibrante", "adorar",
        "movimento", "Movimento", "conversa", "festa", "compartilhar",
        "energia", "contagiante", "celebração", "viver", "intensamente",
        "eletrizante", "ambiente", "perfeito", "social", "momento",
        "dinâmico", "ideal", "trilha", "inesquecível", "incentir",
        "perfazer", "energético", "vibração", "celebrar", "pulsante",
        "vida", "intenso", "intensidade", "batida", "confiança",
        "atmosfera", "riff", "poderoso", "bater", "cativante",
        "conexão", "ritmo"
    ]
})


translation_dict_extroversion = {
    "animar": "animate", "interação": "interaction", "encontro": "encounter",
    "vibrante": "vibrant", "adorar": "adore", "movimento": "movement",
    "Movimento": "movement", "conversa": "conversation", "festa": "party",
    "compartilhar": "share", "energia": "energy", "contagiante": "contagious",
    "celebração": "celebration", "viver": "live", "intensamente": "intensely",
    "eletrizante": "electrifying", "ambiente": "environment", "perfeito": "perfect",
    "social": "social", "momento": "moment", "dinâmico": "dynamic", "ideal": "ideal",
    "trilha": "track", "inesquecível": "unforgettable", "incentir": "encourage",
    "perfazer": "complete", "energético": "energetic", "vibração": "vibration",
    "celebrar": "celebrate", "pulsante": "pulsating", "vida": "life", "intenso": "intense",
    "intensidade": "intensity", "batida": "beat", "confiança": "trust",
    "atmosfera": "atmosphere", "riff": "riff", "poderoso": "powerful",
    "bater": "hit", "cativante": "captivating", "conexão": "connection",
    "ritmo": "rhythm"
}


top_words_extroversion_explanation["Word_EN"] = top_words_extroversion_explanation["Word"].map(translation_dict_extroversion)

# %%
stemmer = PorterStemmer()


def stem_phrase(phrase):
    return " ".join([stemmer.stem(w) for w in phrase.lower().split()])

trait_terms_stemmed = {
    trait: [stem_phrase(word) for word in words]
    for trait, words in trait_terms.items()
}


def process_explanation_words(df, translation_dict, trait_terms_stemmed):

    df["Word_EN"] = df["Word"].map(translation_dict)


    df["Word_EN_Stemmed"] = df["Word_EN"].apply(lambda w: stemmer.stem(w.lower().strip()) if pd.notna(w) else w)


    def match_trait_stemmed(word):
        if pd.isna(word): return None
        stemmed = stemmer.stem(word.lower().strip())
        for trait, phrases in trait_terms_stemmed.items():
            for phrase in phrases:
                if stemmed in phrase.split():
                    return trait
        return None

    df["Matched_Trait_Stemmed"] = df["Word_EN_Stemmed"].apply(match_trait_stemmed)


    total = len(df)
    matched_counts = df["Matched_Trait_Stemmed"].value_counts().to_dict()
    ground_truth_counts = {trait: len(words) for trait, words in trait_terms_stemmed.items()}

    results = []
    for trait in trait_terms_stemmed:
        matched = matched_counts.get(trait, 0)
        ground_truth = ground_truth_counts.get(trait, 1)
        precision = matched / total
        recall = matched / ground_truth
        f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
        results.append({
            "Trait": trait,
            "Precision": round(precision, 3),
            "Recall": round(recall, 3),
            "F1-Score": round(f1, 3)
        })

    metrics_df = pd.DataFrame(results)
    return df, metrics_df

# %%
datasets = {
    "Agreeableness": (top_words_agreeableness_explanation, translation_dict_agreeableness),
    "Neuroticism": (top_words_neuroticism_explanation, translation_dict),
    "Openness": (top_words_openness_explanation, translation_dict_openness),
    "Conscientiousness": (top_words_conscientiousness_explanation, translation_dict_conscientiousness),
    "Extraversion": (top_words_extroversion_explanation, translation_dict_extroversion)
}


all_processed_dfs = {}
all_metrics_dfs = {}

for trait, (df, translation_dict) in datasets.items():
    processed_df, metrics_df = process_explanation_words(df, translation_dict, trait_terms_stemmed)
    all_processed_dfs[trait] = processed_df
    all_metrics_dfs[trait] = metrics_df
    print(f"\n--- {trait} ---")
    print(metrics_df)

summary_metrics = pd.concat(
    all_metrics_dfs.values(),
    keys=all_metrics_dfs.keys()
).reset_index(level=1, drop=True).rename_axis("Explanation_Trait").reset_index()

print("\nCombined Metrics:\n")
print(summary_metrics)
# Out:
# --- Agreeableness ---
#                Trait  Precision  Recall  F1-Score
# 0           Openness      0.062   0.059     0.061
# 1  Conscientiousness      0.000   0.000     0.000
# 2       Extraversion      0.062   0.067     0.065
# 3      Agreeableness      0.156   0.147     0.152
# 4   Neuroticism_High      0.031   0.028     0.029
# 5    Neuroticism_Low      0.000   0.000     0.000
#
# --- Neuroticism ---
#                Trait  Precision  Recall  F1-Score
# 0           Openness      0.000   0.000     0.000
# 1  Conscientiousness      0.000   0.000     0.000
# 2       Extraversion      0.026   0.033     0.029
# 3      Agreeableness      0.079   0.088     0.083
# 4   Neuroticism_High      0.053   0.056     0.054
# 5    Neuroticism_Low      0.237   0.360     0.286
#
# --- Openness ---
#                Trait  Precision  Recall  F1-Score
# 0           Openness      0.273   0.265     0.269
# 1  Conscientiousness      0.000   0.000     0.000
# ...
