# %%
import pandas as pd
import numpy as np
from itertools import combinations
from scipy.stats import kruskal, mannwhitneyu


try:
    import scikit_posthocs as sp
    HAS_SCPH = True
except Exception:
    HAS_SCPH = False


def holm_adjust(pvals):

    m = len(pvals)
    order = np.argsort(pvals)
    adjusted = np.empty(m, dtype=float)
    prev = 0.0
    for rank, idx in enumerate(order, start=1):
        adj = (m - rank + 1) * pvals[idx]
        adj = min(1.0, max(adj, prev))
        adjusted[idx] = adj
        prev = adj
    return adjusted

def pairwise_matrix_from_pvals(labels, pair_pvals):

    mat = pd.DataFrame(np.nan, index=labels, columns=labels, dtype=float)
    for (a, b), p in pair_pvals.items():
        mat.loc[a, b] = p
        mat.loc[b, a] = p
    return mat


construct_prefixes = ["quality", "taste", "listen"]
trait_suffixes = [
    "openness",
    "conscientiousness",
    "extroversion",
    "agreeableness",
    "neuroticism",
    "featurebased",
]



traits_of_interest = ["openness"]


for trait_of_interest in traits_of_interest:

    analysis_df[f"{trait_of_interest}_bin"] = pd.cut(
        analysis_df[trait_of_interest],
        bins=[1.0, 3.6, 5.0],
        labels=["Low", "High"],
        include_lowest=True
    )


    all_results = {}

    for construct_prefix in construct_prefixes:

        constructs_columns = [f"{construct_prefix}_{suffix}" for suffix in trait_suffixes]

        mean_rows = []
        posthoc_results = {}

        levels = [lvl for lvl in analysis_df[f"{trait_of_interest}_bin"].dropna().unique()]

        for level in levels:
            row = {"Trait Level": level}
            subset = analysis_df[analysis_df[f"{trait_of_interest}_bin"] == level]


            for col in constructs_columns:
                if col in analysis_df.columns:
                    row[col] = round(subset[col].mean(), 2)
                else:
                    row[col] = np.nan


            values_per_construct = [subset[col].dropna() for col in constructs_columns if col in analysis_df.columns]
            if sum(len(v) > 0 for v in values_per_construct) >= 2:
                stat, p = kruskal(*values_per_construct)
                row["Kruskal Statistic"] = round(float(stat), 3)
                row["p-value"] = round(float(p), 3)
            else:
                row["Kruskal Statistic"] = np.nan
                row["p-value"] = np.nan


            if HAS_SCPH:
                long_df = pd.DataFrame({
                    "value": pd.concat(values_per_construct, ignore_index=True),
                    "group": np.concatenate([
                        np.repeat(lbl, len(values_per_construct[i]))
                        for i, lbl in enumerate([c for c in constructs_columns if c in analysis_df.columns])
                    ])
                })

                long_df = long_df.replace([np.inf, -np.inf], np.nan).dropna(subset=["value"])
                if long_df["group"].nunique() >= 2 and len(long_df) > 0:
                    dunn = sp.posthoc_dunn(long_df, val_col="value", group_col="group", p_adjust="holm")

                    dunn = dunn.reindex(index=constructs_columns, columns=constructs_columns)
                    posthoc_results[level] = dunn
                else:
                    posthoc_results[level] = pd.DataFrame(index=constructs_columns, columns=constructs_columns, dtype=float)
            else:

                valid_constructs = [c for c in constructs_columns if c in analysis_df.columns]
                pairs = list(combinations(valid_constructs, 2))
                raw_p = []
                valid_pairs = []
                for a, b in pairs:
                    a_vals = subset[a].dropna()
                    b_vals = subset[b].dropna()
                    if len(a_vals) > 0 and len(b_vals) > 0:

                        u_stat, pval = mannwhitneyu(a_vals, b_vals, alternative="two-sided")
                        raw_p.append(pval)
                        valid_pairs.append((a, b))
                if raw_p:
                    adj = holm_adjust(np.array(raw_p, dtype=float))
                    pair_to_adj = {pair: p for pair, p in zip(valid_pairs, adj)}
                    mat = pairwise_matrix_from_pvals(constructs_columns, pair_to_adj)
                    posthoc_results[level] = mat
                else:
                    posthoc_results[level] = pd.DataFrame(index=constructs_columns, columns=constructs_columns, dtype=float)

            mean_rows.append(row)


        mean_table_df = pd.DataFrame(mean_rows)
        final_columns = ["Trait Level"] + constructs_columns + ["Kruskal Statistic", "p-value"]
        mean_table_df = mean_table_df[final_columns]


        all_results[construct_prefix] = {
            "mean_table": mean_table_df,
            "posthoc_results": posthoc_results
        }


    print(f"\n{'='*80}")
    print(f"ANALYSIS BY TRAIT: {trait_of_interest.upper()}")
    print(f"{'='*80}\n")

    for construct_prefix in construct_prefixes:
        print(f"\n{'='*80}")
        print(f"RESULTS FOR: {construct_prefix.upper()} for {trait_of_interest}")
        print(f"{'='*80}\n")

        print(f"Mean Table for {construct_prefix}:")
        print(all_results[construct_prefix]["mean_table"])
        print("\n")

        print(f"Post-hoc Results for {construct_prefix} (High Level Only):")
        if "High" in all_results[construct_prefix]["posthoc_results"]:
            print(all_results[construct_prefix]["posthoc_results"]["High"])
        else:
            print("No High level data available")
        print("\n")
# Out:
# ================================================================================
# ANALYSIS BY TRAIT: OPENNESS
# ================================================================================
#
#
# ================================================================================
# RESULTS FOR: QUALITY for openness
# ================================================================================
#
# Mean Table for quality:
#   Trait Level  quality_openness  quality_conscientiousness  \
# 0         Low              4.20                       4.07
# 1        High              4.24                       4.17
#
#    quality_extroversion  quality_agreeableness  quality_neuroticism  \
# 0                  4.27                   4.22                 4.28
# 1                  4.34                   4.39                 4.35
#
#    quality_featurebased  Kruskal Statistic  p-value
# 0                  4.24              7.124    0.212
# 1                  4.40             15.783    0.007
#
#
# Post-hoc Results for quality (High Level Only):
#                            quality_openness  quality_conscientiousness  \
# quality_openness                        NaN                   1.000000
# quality_conscientiousness          1.000000                        NaN
# quality_extroversion               1.000000                   0.175792
# quality_agreeableness              0.563279                   0.029429
# quality_neuroticism                0.970385                   0.083489
# quality_featurebased               0.514428                   0.025019
#
#                            quality_extroversion  quality_agreeableness  \
# quality_openness                       1.000000               0.563279
# quality_conscientiousness              0.175792               0.029429
# quality_extroversion                        NaN               1.000000
# quality_agreeableness                  1.000000                    NaN
# quality_neuroticism                    1.000000               1.000000
# quality_featurebased                   1.000000               1.000000
#
#                            quality_neuroticism  quality_featurebased
# quality_openness                      0.970385              0.514428
# quality_conscientiousness             0.083489              0.025019
# quality_extroversion                  1.000000              1.000000
# quality_agreeableness                 1.000000              1.000000
# quality_neuroticism                        NaN              1.000000
# quality_featurebased                  1.000000                   NaN
#
#
#
# ================================================================================
# RESULTS FOR: TASTE for openness
# ================================================================================
#
# Mean Table for taste:
#   Trait Level  taste_openness  taste_conscientiousness  taste_extroversion  \
# 0         Low            3.94                     3.81                3.98
# 1        High            3.95                     3.95                4.05
#
#    taste_agreeableness  taste_neuroticism  taste_featurebased  \
# 0                 3.88               4.06                4.08
# 1                 4.19               4.21                4.18
#
#    Kruskal Statistic  p-value
# 0              9.700    0.084
# 1             22.517    0.000
#
#
# Post-hoc Results for taste (High Level Only):
#                          taste_openness  taste_conscientiousness  \
# taste_openness                      NaN                 1.000000
# taste_conscientiousness        1.000000                      NaN
# taste_extroversion             1.000000                 0.967486
# taste_agreeableness            0.076667                 0.016219
# taste_neuroticism              0.035954                 0.006300
# taste_featurebased             0.159197                 0.042944
#
#                          taste_extroversion  taste_agreeableness  \
# taste_openness                     1.000000             0.076667
# taste_conscientiousness            0.967486             0.016219
# taste_extroversion                      NaN             0.587740
# taste_agreeableness                0.587740                  NaN
# taste_neuroticism                  0.308507             1.000000
# taste_featurebased                 0.967486             1.000000
#
#                          taste_neuroticism  taste_featurebased
# taste_openness                    0.035954            0.159197
# taste_conscientiousness           0.006300            0.042944
# taste_extroversion                0.308507            0.967486
# taste_agreeableness               1.000000            1.000000
# taste_neuroticism                      NaN            1.000000
# taste_featurebased                1.000000                 NaN
#
#
#
# ================================================================================
# RESULTS FOR: LISTEN for openness
# ================================================================================
#
# Mean Table for listen:
#   Trait Level  listen_openness  listen_conscientiousness  listen_extroversion  \
# 0         Low             3.85                      3.72                 3.92
# 1        High             3.90                      3.87                 4.06
#
#    listen_agreeableness  listen_neuroticism  listen_featurebased  \
# 0                  3.80                3.96                 4.03
# 1                  4.13                4.21                 4.10
#
#    Kruskal Statistic  p-value
# 0              9.394    0.094
# 1             22.149    0.000
#
#
# Post-hoc Results for listen (High Level Only):
#                           listen_openness  listen_conscientiousness  \
# listen_openness                       NaN                  1.000000
# listen_conscientiousness         1.000000                       NaN
# listen_extroversion              0.901230                  0.352905
# listen_agreeableness             0.231218                  0.041788
# listen_neuroticism               0.012093                  0.001120
# listen_featurebased              0.461105                  0.147909
#
#                           listen_extroversion  listen_agreeableness  \
# listen_openness                      0.901230              0.231218
# listen_conscientiousness             0.352905              0.041788
# listen_extroversion                       NaN              1.000000
# listen_agreeableness                 1.000000                   NaN
# listen_neuroticism                   0.449106              1.000000
# listen_featurebased                  1.000000              1.000000
#
#                           listen_neuroticism  listen_featurebased
# listen_openness                     0.012093             0.461105
# listen_conscientiousness            0.001120             0.147909
# listen_extroversion                 0.449106             1.000000
# listen_agreeableness                1.000000             1.000000
# listen_neuroticism                       NaN             0.901230
# listen_featurebased                 0.901230                  NaN

# %%
traits_of_interest = ["conscientiousness"]

for trait_of_interest in traits_of_interest:


    analysis_df[f"{trait_of_interest}_bin"] = pd.cut(
        analysis_df[trait_of_interest],
        bins=[1.0, 3.6, 5.0],
        labels=["Low", "High"],
        include_lowest=True
    )


    all_results = {}

    for construct_prefix in construct_prefixes:

        constructs_columns = [f"{construct_prefix}_{suffix}" for suffix in trait_suffixes]

        mean_rows = []
        posthoc_results = {}
        levels = [lvl for lvl in analysis_df[f"{trait_of_interest}_bin"].dropna().unique()]

        for level in levels:
            row = {"Trait Level": level}
            subset = analysis_df[analysis_df[f"{trait_of_interest}_bin"] == level]


            for col in constructs_columns:
                if col in analysis_df.columns:
                    row[col] = round(subset[col].mean(), 2)
                else:
                    row[col] = np.nan


            values_per_construct = [subset[col].dropna() for col in constructs_columns if col in analysis_df.columns]
            if sum(len(v) > 0 for v in values_per_construct) >= 2:
                stat, p = kruskal(*values_per_construct)
                row["Kruskal Statistic"] = round(float(stat), 3)
                row["p-value"] = round(float(p), 3)
            else:
                row["Kruskal Statistic"] = np.nan
                row["p-value"] = np.nan


            if HAS_SCPH:
                long_df = pd.DataFrame({
                    "value": pd.concat(values_per_construct, ignore_index=True),
                    "group": np.concatenate([
                        np.repeat(lbl, len(values_per_construct[i]))
                        for i, lbl in enumerate([c for c in constructs_columns if c in analysis_df.columns])
                    ])
                })

                long_df = long_df.replace([np.inf, -np.inf], np.nan).dropna(subset=["value"])
                if long_df["group"].nunique() >= 2 and len(long_df) > 0:
                    dunn = sp.posthoc_dunn(long_df, val_col="value", group_col="group", p_adjust="holm")

                    dunn = dunn.reindex(index=constructs_columns, columns=constructs_columns)
                    posthoc_results[level] = dunn
                else:
                    posthoc_results[level] = pd.DataFrame(index=constructs_columns, columns=constructs_columns, dtype=float)
            else:

                valid_constructs = [c for c in constructs_columns if c in analysis_df.columns]
                pairs = list(combinations(valid_constructs, 2))
                raw_p = []
                valid_pairs = []
                for a, b in pairs:
                    a_vals = subset[a].dropna()
                    b_vals = subset[b].dropna()
                    if len(a_vals) > 0 and len(b_vals) > 0:

                        u_stat, pval = mannwhitneyu(a_vals, b_vals, alternative="two-sided")
                        raw_p.append(pval)
                        valid_pairs.append((a, b))
                if raw_p:
                    adj = holm_adjust(np.array(raw_p, dtype=float))
                    pair_to_adj = {pair: p for pair, p in zip(valid_pairs, adj)}
                    mat = pairwise_matrix_from_pvals(constructs_columns, pair_to_adj)
                    posthoc_results[level] = mat
                else:
                    posthoc_results[level] = pd.DataFrame(index=constructs_columns, columns=constructs_columns, dtype=float)

            mean_rows.append(row)


        mean_table_df = pd.DataFrame(mean_rows)
        final_columns = ["Trait Level"] + constructs_columns + ["Kruskal Statistic", "p-value"]
        mean_table_df = mean_table_df[final_columns]


        all_results[construct_prefix] = {
            "mean_table": mean_table_df,
            "posthoc_results": posthoc_results
        }

    print(f"\n{'='*80}")
    print(f"ANALYSIS BY TRAIT: {trait_of_interest.upper()}")
    print(f"{'='*80}\n")

    for construct_prefix in construct_prefixes:
        print(f"\n{'='*80}")
        print(f"RESULTS FOR: {construct_prefix.upper()} for {trait_of_interest}")
        print(f"{'='*80}\n")

        print(f"Mean Table for {construct_prefix}:")
        print(all_results[construct_prefix]["mean_table"])
        print("\n")

        print(f"Post-hoc Results for {construct_prefix} (High Level Only):")
        if "High" in all_results[construct_prefix]["posthoc_results"]:
            print(all_results[construct_prefix]["posthoc_results"]["High"])
        else:
            print("No High level data available")
        print("\n")
# Out:
# ================================================================================
# ANALYSIS BY TRAIT: CONSCIENTIOUSNESS
# ================================================================================
#
#
# ================================================================================
# RESULTS FOR: QUALITY for conscientiousness
# ================================================================================
#
# Mean Table for quality:
#   Trait Level  quality_openness  quality_conscientiousness  \
# 0        High              4.23                       4.19
# 1         Low              4.23                       4.05
#
#    quality_extroversion  quality_agreeableness  quality_neuroticism  \
# 0                  4.33                   4.38                 4.37
# 1                  4.29                   4.28                 4.25
#
#    quality_featurebased  Kruskal Statistic  p-value
# 0                  4.41             16.057    0.007
# 1                  4.25              8.553    0.128
#
#
# Post-hoc Results for quality (High Level Only):
#                            quality_openness  quality_conscientiousness  \
# quality_openness                        NaN                   1.000000
# quality_conscientiousness          1.000000                        NaN
# quality_extroversion               0.944125                   0.264561
# quality_agreeableness              0.481850                   0.096534
# quality_neuroticism                0.481850                   0.096534
# quality_featurebased               0.170944                   0.019880
#
#                            quality_extroversion  quality_agreeableness  \
# quality_openness                       0.944125               0.481850
# quality_conscientiousness              0.264561               0.096534
# quality_extroversion                        NaN               1.000000
# quality_agreeableness                  1.000000                    NaN
# quality_neuroticism                    1.000000               1.000000
# quality_featurebased                   1.000000               1.000000
#
#                            quality_neuroticism  quality_featurebased
# quality_openness                      0.481850              0.170944
# quality_conscientiousness             0.096534              0.019880
# quality_extroversion                  1.000000              1.000000
# quality_agreeableness                 1.000000              1.000000
# quality_neuroticism                        NaN              1.000000
# quality_featurebased                  1.000000                   NaN
#
#
#
# ================================================================================
# RESULTS FOR: TASTE for conscientiousness
# ================================================================================
#
# Mean Table for taste:
#   Trait Level  taste_openness  taste_conscientiousness  taste_extroversion  \
# 0        High            3.93                     3.94                4.06
# 1         Low            3.98                     3.85                3.98
#
#    taste_agreeableness  taste_neuroticism  taste_featurebased  \
# 0                 4.12               4.23                4.17
# 1                 4.04               4.04                4.12
#
#    Kruskal Statistic  p-value
# 0             21.323    0.001
# 1              8.543    0.129
#
#
# Post-hoc Results for taste (High Level Only):
#                          taste_openness  taste_conscientiousness  \
# taste_openness                      NaN                 1.000000
# taste_conscientiousness        1.000000                      NaN
# taste_extroversion             1.000000                 1.000000
# taste_agreeableness            0.300527                 0.182754
# taste_neuroticism              0.009266                 0.003117
# taste_featurebased             0.122348                 0.063710
#
#                          taste_extroversion  taste_agreeableness  \
# taste_openness                     1.000000             0.300527
# taste_conscientiousness            1.000000             0.182754
# taste_extroversion                      NaN             1.000000
# taste_agreeableness                1.000000                  NaN
# taste_neuroticism                  0.300527             1.000000
# taste_featurebased                 1.000000             1.000000
#
#                          taste_neuroticism  taste_featurebased
# taste_openness                    0.009266            0.122348
# taste_conscientiousness           0.003117            0.063710
# taste_extroversion                0.300527            1.000000
# taste_agreeableness               1.000000            1.000000
# taste_neuroticism                      NaN            1.000000
# taste_featurebased                1.000000                 NaN
#
#
#
# ================================================================================
# RESULTS FOR: LISTEN for conscientiousness
# ================================================================================
#
# Mean Table for listen:
#   Trait Level  listen_openness  listen_conscientiousness  listen_extroversion  \
# 0        High             3.85                      3.84                 4.05
# 1         Low             3.95                      3.78                 3.95
#
#    listen_agreeableness  listen_neuroticism  listen_featurebased  \
# 0                  4.07                4.19                 4.11
# 1                  3.96                4.03                 4.02
#
#    Kruskal Statistic  p-value
# 0             24.990    0.000
# 1              6.791    0.237
#
#
# Post-hoc Results for listen (High Level Only):
#                           listen_openness  listen_conscientiousness  \
# listen_openness                       NaN                  1.000000
# listen_conscientiousness         1.000000                       NaN
# listen_extroversion              0.239623                  0.245534
# listen_agreeableness             0.154460                  0.160090
# listen_neuroticism               0.001775                  0.001781
# listen_featurebased              0.045957                  0.046753
#
#                           listen_extroversion  listen_agreeableness  \
# listen_openness                      0.239623              0.154460
# listen_conscientiousness             0.245534              0.160090
# listen_extroversion                       NaN              1.000000
# listen_agreeableness                 1.000000                   NaN
# listen_neuroticism                   0.651049              0.775335
# listen_featurebased                  1.000000              1.000000
#
#                           listen_neuroticism  listen_featurebased
# listen_openness                     0.001775             0.045957
# listen_conscientiousness            0.001781             0.046753
# listen_extroversion                 0.651049             1.000000
# listen_agreeableness                0.775335             1.000000
# listen_neuroticism                       NaN             1.000000
# listen_featurebased                 1.000000                  NaN

# %%
traits_of_interest = ["extroversion"]

for trait_of_interest in traits_of_interest:


    analysis_df[f"{trait_of_interest}_bin"] = pd.cut(
        analysis_df[trait_of_interest],
        bins=[1.0, 3.6, 5.0],
        labels=["Low", "High"],
        include_lowest=True
    )


    all_results = {}

    for construct_prefix in construct_prefixes:

        constructs_columns = [f"{construct_prefix}_{suffix}" for suffix in trait_suffixes]

        mean_rows = []
        posthoc_results = {}
        levels = [lvl for lvl in analysis_df[f"{trait_of_interest}_bin"].dropna().unique()]

        for level in levels:
            row = {"Trait Level": level}
            subset = analysis_df[analysis_df[f"{trait_of_interest}_bin"] == level]


            for col in constructs_columns:
                if col in analysis_df.columns:
                    row[col] = round(subset[col].mean(), 2)
                else:
                    row[col] = np.nan


            values_per_construct = [subset[col].dropna() for col in constructs_columns if col in analysis_df.columns]
            if sum(len(v) > 0 for v in values_per_construct) >= 2:
                stat, p = kruskal(*values_per_construct)
                row["Kruskal Statistic"] = round(float(stat), 3)
                row["p-value"] = round(float(p), 3)
            else:
                row["Kruskal Statistic"] = np.nan
                row["p-value"] = np.nan


            if HAS_SCPH:
                long_df = pd.DataFrame({
                    "value": pd.concat(values_per_construct, ignore_index=True),
                    "group": np.concatenate([
                        np.repeat(lbl, len(values_per_construct[i]))
                        for i, lbl in enumerate([c for c in constructs_columns if c in analysis_df.columns])
                    ])
                })

                long_df = long_df.replace([np.inf, -np.inf], np.nan).dropna(subset=["value"])
                if long_df["group"].nunique() >= 2 and len(long_df) > 0:
                    dunn = sp.posthoc_dunn(long_df, val_col="value", group_col="group", p_adjust="holm")

                    dunn = dunn.reindex(index=constructs_columns, columns=constructs_columns)
                    posthoc_results[level] = dunn
                else:
                    posthoc_results[level] = pd.DataFrame(index=constructs_columns, columns=constructs_columns, dtype=float)
            else:

                valid_constructs = [c for c in constructs_columns if c in analysis_df.columns]
                pairs = list(combinations(valid_constructs, 2))
                raw_p = []
                valid_pairs = []
                for a, b in pairs:
                    a_vals = subset[a].dropna()
                    b_vals = subset[b].dropna()
                    if len(a_vals) > 0 and len(b_vals) > 0:

                        u_stat, pval = mannwhitneyu(a_vals, b_vals, alternative="two-sided")
                        raw_p.append(pval)
                        valid_pairs.append((a, b))
                if raw_p:
                    adj = holm_adjust(np.array(raw_p, dtype=float))
                    pair_to_adj = {pair: p for pair, p in zip(valid_pairs, adj)}
                    mat = pairwise_matrix_from_pvals(constructs_columns, pair_to_adj)
                    posthoc_results[level] = mat
                else:
                    posthoc_results[level] = pd.DataFrame(index=constructs_columns, columns=constructs_columns, dtype=float)

            mean_rows.append(row)


        mean_table_df = pd.DataFrame(mean_rows)
        final_columns = ["Trait Level"] + constructs_columns + ["Kruskal Statistic", "p-value"]
        mean_table_df = mean_table_df[final_columns]


        all_results[construct_prefix] = {
            "mean_table": mean_table_df,
            "posthoc_results": posthoc_results
        }

    print(f"\n{'='*80}")
    print(f"ANALYSIS BY TRAIT: {trait_of_interest.upper()}")
    print(f"{'='*80}\n")

    for construct_prefix in construct_prefixes:
        print(f"\n{'='*80}")
        print(f"RESULTS FOR: {construct_prefix.upper()} for {trait_of_interest}")
        print(f"{'='*80}\n")

        print(f"Mean Table for {construct_prefix}:")
        print(all_results[construct_prefix]["mean_table"])
        print("\n")

        print(f"Post-hoc Results for {construct_prefix} (High Level Only):")
        if "High" in all_results[construct_prefix]["posthoc_results"]:
            print(all_results[construct_prefix]["posthoc_results"]["High"])
        else:
            print("No High level data available")
        print("\n")
# Out:
# ================================================================================
# ANALYSIS BY TRAIT: EXTROVERSION
# ================================================================================
#
#
# ================================================================================
# RESULTS FOR: QUALITY for extroversion
# ================================================================================
#
# Mean Table for quality:
#   Trait Level  quality_openness  quality_conscientiousness  \
# 0         Low              4.31                       4.15
# 1        High              4.06                       4.12
#
#    quality_extroversion  quality_agreeableness  quality_neuroticism  \
# 0                  4.33                   4.35                 4.34
# 1                  4.29                   4.31                 4.30
#
#    quality_featurebased  Kruskal Statistic  p-value
# 0                  4.35             15.160    0.010
# 1                  4.37             11.977    0.035
#
#
# Post-hoc Results for quality (High Level Only):
#                            quality_openness  quality_conscientiousness  \
# quality_openness                        NaN                   1.000000
# quality_conscientiousness          1.000000                        NaN
# quality_extroversion               0.490078                   1.000000
# quality_agreeableness              0.336070                   0.809787
# quality_neuroticism                0.363890                   0.862507
# quality_featurebased               0.108102                   0.363890
#
#                            quality_extroversion  quality_agreeableness  \
# quality_openness                       0.490078               0.336070
# quality_conscientiousness              1.000000               0.809787
# quality_extroversion                        NaN               1.000000
# quality_agreeableness                  1.000000                    NaN
# quality_neuroticism                    1.000000               1.000000
# quality_featurebased                   1.000000               1.000000
#
#                            quality_neuroticism  quality_featurebased
# quality_openness                      0.363890              0.108102
# quality_conscientiousness             0.862507              0.363890
# quality_extroversion                  1.000000              1.000000
# quality_agreeableness                 1.000000              1.000000
# quality_neuroticism                        NaN              1.000000
# quality_featurebased                  1.000000                   NaN
#
#
#
# ================================================================================
# RESULTS FOR: TASTE for extroversion
# ================================================================================
#
# Mean Table for taste:
#   Trait Level  taste_openness  taste_conscientiousness  taste_extroversion  \
# 0         Low            4.02                     3.92                4.02
# 1        High            3.79                     3.88                4.06
#
#    taste_agreeableness  taste_neuroticism  taste_featurebased  \
# 0                 4.08               4.19                4.13
# 1                 4.12               4.10                4.18
#
#    Kruskal Statistic  p-value
# 0             17.658    0.003
# 1             15.376    0.009
#
#
# Post-hoc Results for taste (High Level Only):
#                          taste_openness  taste_conscientiousness  \
# taste_openness                      NaN                 1.000000
# taste_conscientiousness        1.000000                      NaN
# taste_extroversion             0.653046                 1.000000
# taste_agreeableness            0.117811                 0.271558
# taste_neuroticism              0.334520                 0.795722
# taste_featurebased             0.040523                 0.099664
#
#                          taste_extroversion  taste_agreeableness  \
# taste_openness                     0.653046             0.117811
# taste_conscientiousness            1.000000             0.271558
# taste_extroversion                      NaN             1.000000
# taste_agreeableness                1.000000                  NaN
# taste_neuroticism                  1.000000             1.000000
# taste_featurebased                 1.000000             1.000000
#
#                          taste_neuroticism  taste_featurebased
# taste_openness                    0.334520            0.040523
# taste_conscientiousness           0.795722            0.099664
# taste_extroversion                1.000000            1.000000
# taste_agreeableness               1.000000            1.000000
# taste_neuroticism                      NaN            1.000000
# taste_featurebased                1.000000                 NaN
#
#
#
# ================================================================================
# RESULTS FOR: LISTEN for extroversion
# ================================================================================
#
# Mean Table for listen:
#   Trait Level  listen_openness  listen_conscientiousness  listen_extroversion  \
# 0         Low             3.98                      3.80                 3.98
# 1        High             3.68                      3.86                 4.09
#
#    listen_agreeableness  listen_neuroticism  listen_featurebased  \
# 0                  4.03                4.18                 4.06
# 1                  4.02                4.04                 4.10
#
#    Kruskal Statistic  p-value
# 0             22.478    0.000
# 1             16.201    0.006
#
#
# Post-hoc Results for listen (High Level Only):
#                           listen_openness  listen_conscientiousness  \
# listen_openness                       NaN                  1.000000
# listen_conscientiousness         1.000000                       NaN
# listen_extroversion              0.023473                  1.000000
# listen_agreeableness             0.079539                  1.000000
# listen_neuroticism               0.096793                  1.000000
# listen_featurebased              0.015235                  0.811783
#
#                           listen_extroversion  listen_agreeableness  \
# listen_openness                      0.023473              0.079539
# listen_conscientiousness             1.000000              1.000000
# listen_extroversion                       NaN              1.000000
# listen_agreeableness                 1.000000                   NaN
# listen_neuroticism                   1.000000              1.000000
# listen_featurebased                  1.000000              1.000000
#
#                           listen_neuroticism  listen_featurebased
# listen_openness                     0.096793             0.015235
# listen_conscientiousness            1.000000             0.811783
# listen_extroversion                 1.000000             1.000000
# listen_agreeableness                1.000000             1.000000
# listen_neuroticism                       NaN             1.000000
# listen_featurebased                 1.000000                  NaN

# %%
traits_of_interest = ["agreeableness"]

for trait_of_interest in traits_of_interest:


    analysis_df[f"{trait_of_interest}_bin"] = pd.cut(
        analysis_df[trait_of_interest],
        bins=[1.0, 3.6, 5.0],
        labels=["Low", "High"],
        include_lowest=True
    )


    all_results = {}

    for construct_prefix in construct_prefixes:

        constructs_columns = [f"{construct_prefix}_{suffix}" for suffix in trait_suffixes]

        mean_rows = []
        posthoc_results = {}
        levels = [lvl for lvl in analysis_df[f"{trait_of_interest}_bin"].dropna().unique()]

        for level in levels:
            row = {"Trait Level": level}
            subset = analysis_df[analysis_df[f"{trait_of_interest}_bin"] == level]


            for col in constructs_columns:
                if col in analysis_df.columns:
                    row[col] = round(subset[col].mean(), 2)
                else:
                    row[col] = np.nan


            values_per_construct = [subset[col].dropna() for col in constructs_columns if col in analysis_df.columns]
            if sum(len(v) > 0 for v in values_per_construct) >= 2:
                stat, p = kruskal(*values_per_construct)
                row["Kruskal Statistic"] = round(float(stat), 3)
                row["p-value"] = round(float(p), 3)
            else:
                row["Kruskal Statistic"] = np.nan
                row["p-value"] = np.nan


            if HAS_SCPH:
                long_df = pd.DataFrame({
                    "value": pd.concat(values_per_construct, ignore_index=True),
                    "group": np.concatenate([
                        np.repeat(lbl, len(values_per_construct[i]))
                        for i, lbl in enumerate([c for c in constructs_columns if c in analysis_df.columns])
                    ])
                })

                long_df = long_df.replace([np.inf, -np.inf], np.nan).dropna(subset=["value"])
                if long_df["group"].nunique() >= 2 and len(long_df) > 0:
                    dunn = sp.posthoc_dunn(long_df, val_col="value", group_col="group", p_adjust="holm")

                    dunn = dunn.reindex(index=constructs_columns, columns=constructs_columns)
                    posthoc_results[level] = dunn
                else:
                    posthoc_results[level] = pd.DataFrame(index=constructs_columns, columns=constructs_columns, dtype=float)
            else:

                valid_constructs = [c for c in constructs_columns if c in analysis_df.columns]
                pairs = list(combinations(valid_constructs, 2))
                raw_p = []
                valid_pairs = []
                for a, b in pairs:
                    a_vals = subset[a].dropna()
                    b_vals = subset[b].dropna()
                    if len(a_vals) > 0 and len(b_vals) > 0:

                        u_stat, pval = mannwhitneyu(a_vals, b_vals, alternative="two-sided")
                        raw_p.append(pval)
                        valid_pairs.append((a, b))
                if raw_p:
                    adj = holm_adjust(np.array(raw_p, dtype=float))
                    pair_to_adj = {pair: p for pair, p in zip(valid_pairs, adj)}
                    mat = pairwise_matrix_from_pvals(constructs_columns, pair_to_adj)
                    posthoc_results[level] = mat
                else:
                    posthoc_results[level] = pd.DataFrame(index=constructs_columns, columns=constructs_columns, dtype=float)

            mean_rows.append(row)


        mean_table_df = pd.DataFrame(mean_rows)
        final_columns = ["Trait Level"] + constructs_columns + ["Kruskal Statistic", "p-value"]
        mean_table_df = mean_table_df[final_columns]


        all_results[construct_prefix] = {
            "mean_table": mean_table_df,
            "posthoc_results": posthoc_results
        }

    print(f"\n{'='*80}")
    print(f"ANALYSIS BY TRAIT: {trait_of_interest.upper()}")
    print(f"{'='*80}\n")

    for construct_prefix in construct_prefixes:
        print(f"\n{'='*80}")
        print(f"RESULTS FOR: {construct_prefix.upper()} for {trait_of_interest}")
        print(f"{'='*80}\n")

        print(f"Mean Table for {construct_prefix}:")
        print(all_results[construct_prefix]["mean_table"])
        print("\n")

        print(f"Post-hoc Results for {construct_prefix} (High Level Only):")
        if "High" in all_results[construct_prefix]["posthoc_results"]:
            print(all_results[construct_prefix]["posthoc_results"]["High"])
        else:
            print("No High level data available")
        print("\n")
# Out:
# ================================================================================
# ANALYSIS BY TRAIT: AGREEABLENESS
# ================================================================================
#
#
# ================================================================================
# RESULTS FOR: QUALITY for agreeableness
# ================================================================================
#
# Mean Table for quality:
#   Trait Level  quality_openness  quality_conscientiousness  \
# 0        High              4.25                       4.16
# 1         Low              4.00                       3.92
#
#    quality_extroversion  quality_agreeableness  quality_neuroticism  \
# 0                  4.35                   4.37                 4.35
# 1                  3.92                   3.96                 4.08
#
#    quality_featurebased  Kruskal Statistic  p-value
# 0                  4.36             20.922    0.001
# 1                  4.29              4.621    0.464
#
#
# Post-hoc Results for quality (High Level Only):
#                            quality_openness  quality_conscientiousness  \
# quality_openness                        NaN                   0.797957
# quality_conscientiousness          0.797957                        NaN
# quality_extroversion               0.797957                   0.012731
# quality_agreeableness              0.576116                   0.004670
# quality_neuroticism                0.751595                   0.010570
# quality_featurebased               0.721787                   0.008024
#
#                            quality_extroversion  quality_agreeableness  \
# quality_openness                       0.797957               0.576116
# quality_conscientiousness              0.012731               0.004670
# quality_extroversion                        NaN               1.000000
# quality_agreeableness                  1.000000                    NaN
# quality_neuroticism                    1.000000               1.000000
# quality_featurebased                   1.000000               1.000000
#
#                            quality_neuroticism  quality_featurebased
# quality_openness                      0.751595              0.721787
# quality_conscientiousness             0.010570              0.008024
# quality_extroversion                  1.000000              1.000000
# quality_agreeableness                 1.000000              1.000000
# quality_neuroticism                        NaN              1.000000
# quality_featurebased                  1.000000                   NaN
#
#
#
# ================================================================================
# RESULTS FOR: TASTE for agreeableness
# ================================================================================
#
# Mean Table for taste:
#   Trait Level  taste_openness  taste_conscientiousness  taste_extroversion  \
# 0        High            3.97                     3.93                4.08
# 1         Low            3.62                     3.58                3.38
#
#    taste_agreeableness  taste_neuroticism  taste_featurebased  \
# 0                 4.14               4.21                4.17
# 1                 3.46               3.46                3.83
#
#    Kruskal Statistic  p-value
# 0             27.817    0.000
# 1              3.867    0.569
#
#
# Post-hoc Results for taste (High Level Only):
#                          taste_openness  taste_conscientiousness  \
# taste_openness                      NaN                 1.000000
# taste_conscientiousness        1.000000                      NaN
# taste_extroversion             1.000000                 0.241262
# taste_agreeableness            0.216708                 0.015000
# taste_neuroticism              0.011807                 0.000298
# taste_featurebased             0.058487                 0.003014
#
#                          taste_extroversion  taste_agreeableness  \
# taste_openness                     1.000000             0.216708
# taste_conscientiousness            0.241262             0.015000
# taste_extroversion                      NaN             1.000000
# taste_agreeableness                1.000000                  NaN
# taste_neuroticism                  0.296093             1.000000
# taste_featurebased                 0.829071             1.000000
#
#                          taste_neuroticism  taste_featurebased
# taste_openness                    0.011807            0.058487
# taste_conscientiousness           0.000298            0.003014
# taste_extroversion                0.296093            0.829071
# taste_agreeableness               1.000000            1.000000
# taste_neuroticism                      NaN            1.000000
# taste_featurebased                1.000000                 NaN
#
#
#
# ================================================================================
# RESULTS FOR: LISTEN for agreeableness
# ================================================================================
#
# Mean Table for listen:
#   Trait Level  listen_openness  listen_conscientiousness  listen_extroversion  \
# 0        High             3.91                      3.85                 4.07
# 1         Low             3.58                      3.42                 3.29
#
#    listen_agreeableness  listen_neuroticism  listen_featurebased  \
# 0                  4.07                4.17                 4.09
# 1                  3.42                3.62                 3.83
#
#    Kruskal Statistic  p-value
# 0             26.515    0.000
# 1              5.522    0.356
#
#
# Post-hoc Results for listen (High Level Only):
#                           listen_openness  listen_conscientiousness  \
# listen_openness                       NaN                  1.000000
# listen_conscientiousness         1.000000                       NaN
# listen_extroversion              0.399556                  0.077833
# listen_agreeableness             0.284512                  0.044696
# listen_neuroticism               0.005579                  0.000275
# listen_featurebased              0.134657                  0.017253
#
#                           listen_extroversion  listen_agreeableness  \
# listen_openness                      0.399556              0.284512
# listen_conscientiousness             0.077833              0.044696
# listen_extroversion                       NaN              1.000000
# listen_agreeableness                 1.000000                   NaN
# listen_neuroticism                   0.610629              0.667201
# listen_featurebased                  1.000000              1.000000
#
#                           listen_neuroticism  listen_featurebased
# listen_openness                     0.005579             0.134657
# listen_conscientiousness            0.000275             0.017253
# listen_extroversion                 0.610629             1.000000
# listen_agreeableness                0.667201             1.000000
# listen_neuroticism                       NaN             1.000000
# listen_featurebased                 1.000000                  NaN

# %%
traits_of_interest = ["neuroticism"]

for trait_of_interest in traits_of_interest:


    analysis_df[f"{trait_of_interest}_bin"] = pd.cut(
        analysis_df[trait_of_interest],
        bins=[1.0, 3.6, 5.0],
        labels=["Low", "High"],
        include_lowest=True
    )


    all_results = {}

    for construct_prefix in construct_prefixes:

        constructs_columns = [f"{construct_prefix}_{suffix}" for suffix in trait_suffixes]

        mean_rows = []
        posthoc_results = {}
        levels = [lvl for lvl in analysis_df[f"{trait_of_interest}_bin"].dropna().unique()]

        for level in levels:
            row = {"Trait Level": level}
            subset = analysis_df[analysis_df[f"{trait_of_interest}_bin"] == level]


            for col in constructs_columns:
                if col in analysis_df.columns:
                    row[col] = round(subset[col].mean(), 2)
                else:
                    row[col] = np.nan


            values_per_construct = [subset[col].dropna() for col in constructs_columns if col in analysis_df.columns]
            if sum(len(v) > 0 for v in values_per_construct) >= 2:
                stat, p = kruskal(*values_per_construct)
                row["Kruskal Statistic"] = round(float(stat), 3)
                row["p-value"] = round(float(p), 3)
            else:
                row["Kruskal Statistic"] = np.nan
                row["p-value"] = np.nan


            if HAS_SCPH:
                long_df = pd.DataFrame({
                    "value": pd.concat(values_per_construct, ignore_index=True),
                    "group": np.concatenate([
                        np.repeat(lbl, len(values_per_construct[i]))
                        for i, lbl in enumerate([c for c in constructs_columns if c in analysis_df.columns])
                    ])
                })

                long_df = long_df.replace([np.inf, -np.inf], np.nan).dropna(subset=["value"])
                if long_df["group"].nunique() >= 2 and len(long_df) > 0:
                    dunn = sp.posthoc_dunn(long_df, val_col="value", group_col="group", p_adjust="holm")

                    dunn = dunn.reindex(index=constructs_columns, columns=constructs_columns)
                    posthoc_results[level] = dunn
                else:
                    posthoc_results[level] = pd.DataFrame(index=constructs_columns, columns=constructs_columns, dtype=float)
            else:

                valid_constructs = [c for c in constructs_columns if c in analysis_df.columns]
                pairs = list(combinations(valid_constructs, 2))
                raw_p = []
                valid_pairs = []
                for a, b in pairs:
                    a_vals = subset[a].dropna()
                    b_vals = subset[b].dropna()
                    if len(a_vals) > 0 and len(b_vals) > 0:

                        u_stat, pval = mannwhitneyu(a_vals, b_vals, alternative="two-sided")
                        raw_p.append(pval)
                        valid_pairs.append((a, b))
                if raw_p:
                    adj = holm_adjust(np.array(raw_p, dtype=float))
                    pair_to_adj = {pair: p for pair, p in zip(valid_pairs, adj)}
                    mat = pairwise_matrix_from_pvals(constructs_columns, pair_to_adj)
                    posthoc_results[level] = mat
                else:
                    posthoc_results[level] = pd.DataFrame(index=constructs_columns, columns=constructs_columns, dtype=float)

            mean_rows.append(row)


        mean_table_df = pd.DataFrame(mean_rows)
        final_columns = ["Trait Level"] + constructs_columns + ["Kruskal Statistic", "p-value"]
        mean_table_df = mean_table_df[final_columns]


        all_results[construct_prefix] = {
            "mean_table": mean_table_df,
            "posthoc_results": posthoc_results
        }

    print(f"\n{'='*80}")
    print(f"ANALYSIS BY TRAIT: {trait_of_interest.upper()}")
    print(f"{'='*80}\n")

    for construct_prefix in construct_prefixes:
        print(f"\n{'='*80}")
        print(f"RESULTS FOR: {construct_prefix.upper()} for {trait_of_interest}")
        print(f"{'='*80}\n")

        print(f"Mean Table for {construct_prefix}:")
        print(all_results[construct_prefix]["mean_table"])
        print("\n")

        print(f"Post-hoc Results for {construct_prefix} (High Level Only):")
        if "High" in all_results[construct_prefix]["posthoc_results"]:
            print(all_results[construct_prefix]["posthoc_results"]["High"])
        else:
            print("No High level data available")
        print("\n")
# Out:
# ================================================================================
# ANALYSIS BY TRAIT: NEUROTICISM
# ================================================================================
#
#
# ================================================================================
# RESULTS FOR: QUALITY for neuroticism
# ================================================================================
#
# Mean Table for quality:
#   Trait Level  quality_openness  quality_conscientiousness  \
# 0         Low              4.25                       4.16
# 1        High              4.20                       4.10
#
#    quality_extroversion  quality_agreeableness  quality_neuroticism  \
# 0                  4.30                   4.30                 4.26
# 1                  4.35                   4.41                 4.45
#
#    quality_featurebased  Kruskal Statistic  p-value
# 0                  4.34             10.290    0.067
# 1                  4.38             16.314    0.006
#
#
# Post-hoc Results for quality (High Level Only):
#                            quality_openness  quality_conscientiousness  \
# quality_openness                        NaN                   1.000000
# quality_conscientiousness          1.000000                        NaN
# quality_extroversion               1.000000                   0.200956
# quality_agreeableness              0.628973                   0.081048
# quality_neuroticism                0.160376                   0.011199
# quality_featurebased               1.000000                   0.193300
#
#                            quality_extroversion  quality_agreeableness  \
# quality_openness                       1.000000               0.628973
# quality_conscientiousness              0.200956               0.081048
# quality_extroversion                        NaN               1.000000
# quality_agreeableness                  1.000000                    NaN
# quality_neuroticism                    1.000000               1.000000
# quality_featurebased                   1.000000               1.000000
#
#                            quality_neuroticism  quality_featurebased
# quality_openness                      0.160376                1.0000
# quality_conscientiousness             0.011199                0.1933
# quality_extroversion                  1.000000                1.0000
# quality_agreeableness                 1.000000                1.0000
# quality_neuroticism                        NaN                1.0000
# quality_featurebased                  1.000000                   NaN
#
#
#
# ================================================================================
# RESULTS FOR: TASTE for neuroticism
# ================================================================================
#
# Mean Table for taste:
#   Trait Level  taste_openness  taste_conscientiousness  taste_extroversion  \
# 0         Low            3.92                     3.87                4.06
# 1        High            4.00                     3.98                3.97
#
#    taste_agreeableness  taste_neuroticism  taste_featurebased  \
# 0                 4.04               4.08                4.09
# 1                 4.19               4.32                4.26
#
#    Kruskal Statistic  p-value
# 0             13.705    0.018
# 1             17.258    0.004
#
#
# Post-hoc Results for taste (High Level Only):
#                          taste_openness  taste_conscientiousness  \
# taste_openness                      NaN                 1.000000
# taste_conscientiousness        1.000000                      NaN
# taste_extroversion             1.000000                 1.000000
# taste_agreeableness            1.000000                 0.614342
# taste_neuroticism              0.079588                 0.010111
# taste_featurebased             0.614342                 0.143071
#
#                          taste_extroversion  taste_agreeableness  \
# taste_openness                     1.000000             1.000000
# taste_conscientiousness            1.000000             0.614342
# taste_extroversion                      NaN             1.000000
# taste_agreeableness                1.000000                  NaN
# taste_neuroticism                  0.077184             0.815149
# taste_featurebased                 0.614342             1.000000
#
#                          taste_neuroticism  taste_featurebased
# taste_openness                    0.079588            0.614342
# taste_conscientiousness           0.010111            0.143071
# taste_extroversion                0.077184            0.614342
# taste_agreeableness               0.815149            1.000000
# taste_neuroticism                      NaN            1.000000
# taste_featurebased                1.000000                 NaN
#
#
#
# ================================================================================
# RESULTS FOR: LISTEN for neuroticism
# ================================================================================
#
# Mean Table for listen:
#   Trait Level  listen_openness  listen_conscientiousness  listen_extroversion  \
# 0         Low             3.87                      3.81                 4.04
# 1        High             3.93                      3.85                 3.96
#
#    listen_agreeableness  listen_neuroticism  listen_featurebased  \
# 0                  3.99                4.08                 4.06
# 1                  4.10                4.24                 4.09
#
#    Kruskal Statistic  p-value
# 0             15.097    0.010
# 1             15.264    0.009
#
#
# Post-hoc Results for listen (High Level Only):
#                           listen_openness  listen_conscientiousness  \
# listen_openness                       NaN                  1.000000
# listen_conscientiousness         1.000000                       NaN
# listen_extroversion              1.000000                  1.000000
# listen_agreeableness             1.000000                  0.251576
# listen_neuroticism               0.173421                  0.005505
# listen_featurebased              1.000000                  0.389474
#
#                           listen_extroversion  listen_agreeableness  \
# listen_openness                      1.000000              1.000000
# listen_conscientiousness             1.000000              0.251576
# listen_extroversion                       NaN              1.000000
# listen_agreeableness                 1.000000                   NaN
# listen_neuroticism                   0.243178              1.000000
# listen_featurebased                  1.000000              1.000000
#
#                           listen_neuroticism  listen_featurebased
# listen_openness                     0.173421             1.000000
# listen_conscientiousness            0.005505             0.389474
# listen_extroversion                 0.243178             1.000000
# listen_agreeableness                1.000000             1.000000
# listen_neuroticism                       NaN             0.941938
# listen_featurebased                 0.941938                  NaN
